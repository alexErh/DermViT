# %%
import zipfile, os

zip_path  = './ham10000.zip'
dest_path = './data/ham10000/'

os.makedirs(dest_path, exist_ok=True)

print('Extracting...')
with zipfile.ZipFile(zip_path, 'r') as z:
    z.extractall(dest_path)
print(f'Done! Files in: {dest_path}')
